# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data= pd.read_csv('Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
data=data.drop(['customerID'],axis=1)
data.head()
# Out:
#    gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female              0     Yes  ...          29.85         29.85    No
# 1    Male              0      No  ...          56.95        1889.5    No
# 2    Male              0      No  ...          53.85        108.15   Yes
# 3    Male              0      No  ...          42.30       1840.75    No
# 4  Female              0      No  ...          70.70        151.65   Yes
#
# [5 rows x 20 columns]

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# Churn               7043 non-null object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
data=pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#    SeniorCitizen  tenure  ...  TotalCharges_999.9  Churn_Yes
# 0              0       1  ...                   0          0
# 1              0      34  ...                   0          0
# 2              0       2  ...                   0          1
# 3              0      45  ...                   0          0
# 4              0       2  ...                   0          1
#
# [5 rows x 6560 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Columns: 6560 entries, SeniorCitizen to Churn_Yes
# dtypes: float64(1), int64(2), uint8(6557)
# memory usage: 44.2 MB

# %%
X = data.drop(['Churn_Yes'],axis=1)
Y = data['Churn_Yes']
print(X.shape,'\n',Y.shape)
# Out:
# (7043, 6559)
#  (7043,)

# %%
X = X.astype('float32')
Y = Y.astype('float32')

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X ,Y , test_size =.10 ,random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from keras.utils.np_utils import to_categorical
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

# %%
Nx=X_train.shape[1:][0]
Ny=Y_train.shape[1:][0]
print(Nx,Ny)
# Out:
# 6559 2

# %%
from tensorflow.keras.layers import Input, Dense
from keras.models import Sequential

input_layer = Input(shape = X_train.shape[1:])
hidden_layer = Dense(20, activation = 'relu',)(input_layer)
hidden_layer = Dense(20, activation = 'relu',)(input_layer)
output_layer = Dense(2, activation = 'sigmoid')(hidden_layer)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
model = Model(inputs=[input_layer], outputs=[output_layer])
model.compile(optimizer=optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        [(None, 6559)]            0
# _________________________________________________________________
# dense_95 (Dense)             (None, 20)                131200
# _________________________________________________________________
# dense_96 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 131,242
# Trainable params: 131,242
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=25)
# Out:
# Epoch 1/25
# 6338/6338 [==============================] - 2s 368us/sample - loss: 0.7313 - acc: 0.5475
# Epoch 2/25
# 6338/6338 [==============================] - 2s 315us/sample - loss: 0.4922 - acc: 0.7507
# Epoch 3/25
# 6338/6338 [==============================] - 2s 315us/sample - loss: 0.3440 - acc: 0.7843
# Epoch 4/25
# 6338/6338 [==============================] - 2s 319us/sample - loss: 0.2595 - acc: 0.8113
# Epoch 5/25
# 6338/6338 [==============================] - 2s 309us/sample - loss: 0.2087 - acc: 0.8272
# Epoch 6/25
# 6338/6338 [==============================] - 2s 319us/sample - loss: 0.1743 - acc: 0.8346
# Epoch 7/25
# 6338/6338 [==============================] - 2s 311us/sample - loss: 0.1525 - acc: 0.8501
# Epoch 8/25
# 6338/6338 [==============================] - 2s 312us/sample - loss: 0.1398 - acc: 0.8645
# Epoch 9/25
# 6338/6338 [==============================] - 2s 318us/sample - loss: 0.1299 - acc: 0.8802
# Epoch 10/25
# 6338/6338 [==============================] - 2s 309us/sample - loss: 0.1210 - acc: 0.9123
# Epoch 11/25
# 6338/6338 [==============================] - 2s 315us/sample - loss: 0.0929 - acc: 0.9582
# Epoch 12/25
# 6338/6338 [==============================] - 2s 313us/sample - loss: 0.0483 - acc: 0.9781
# Epoch 13/25
# 6338/6338 [==============================] - 2s 309us/sample - loss: 0.0348 - acc: 0.9795
# Epoch 14/25
# 6338/6338 [==============================] - 2s 306us/sample - loss: 0.0311 - acc: 0.9809
# Epoch 15/25
# 6338/6338 [==============================] - 2s 311us/sample - loss: 0.0295 - acc: 0.9826
# Epoch 16/25
# 6338/6338 [==============================] - 2s 313us/sample - loss: 0.0282 - acc: 0.9823
# Epoch 17/25
# 6338/6338 [==============================] - 2s 311us/sample - loss: 0.0267 - acc: 0.9831
# Epoch 18/25
# 6338/6338 [==============================] - 2s 309us/sample - loss: 0.0264 - acc: 0.9817
# Epoch 19/25
# 6338/6338 [==============================] - 2s 311us/sample - loss: 0.0255 - acc: 0.9833
# Epoch 20/25
# 6338/6338 [==============================] - 2s 310us/sample - loss: 0.0248 - acc: 0.9831
# Epoch 21/25
# 6338/6338 [==============================] - 2s 311us/sample - loss: 0.0249 - acc: 0.9836
# Epoch 22/25
# 6338/6338 [==============================] - 2s 309us/sample - loss: 0.0239 - acc: 0.9836
# Epoch 23/25
# 6338/6338 [==============================] - 2s 312us/sample - loss: 0.0233 - acc: 0.9844
# Epoch 24/25
# 6338/6338 [==============================] - 2s 312us/sample - loss: 0.0229 - acc: 0.9837
# Epoch 25/25
# 6338/6338 [==============================] - 2s 308us/sample - loss: 0.0222 - acc: 0.9849

# %%
from sklearn.metrics import confusion_matrix
loss, accuracy = model.evaluate(X_test, Y_test,verbose=0)  # Evaluate the model
print('Accuracy :%0.3f'%accuracy)
# Out:
# Accuracy :0.780

# %%
history.history.keys()
import matplotlib.pyplot as plt
plt.plot(range(len(history.history['acc'])), history.history['acc'])
plt.show()
